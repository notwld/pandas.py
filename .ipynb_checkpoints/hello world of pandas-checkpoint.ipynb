# %%
import pandas as pd

# %%
data = pd.read_csv("netflix.csv")

# %%
data.head(n=10)
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
# 6  For mature audiences.  May not be suitable for...                110
# ...

# %%
data.tail(n=10)
# Out:
#                           title rating  \
# 990           My Animal Friends   TV-Y
# 991          Dawn of the Croods  TV-Y7
# 992  Alpha and Omega: Dino Digs   TV-G
# 993   Wiener Dog Internationals      G
# 994                    Pup Star      G
# 995                     The BFG     PG
# 996     The Secret Life of Pets     PG
# 997            Precious Puppies   TV-G
# 998                 Beary Tales   TV-G
# 999             Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 990                             Suitable for all ages.                 10
# 991             Suitable for children ages 7 and older                 41
# 992                             Suitable for all ages.                 35
# 993          General Audiences. Suitable for all ages.                 35
# 994          General Audiences. Suitable for all ages.                 35
# 995  for action/peril, some scary moments and brief...                 60
# ...

# %%
data.columns
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 7)

# %% [markdown]
# # LOC = LABEL BASED SELECTION
# # ILOC = INDEX LABEL BASED SELECTION

# %%
data.loc[(data.rating=='PG-13')]
# Out:
#                             title rating  \
# 0                    White Chicks  PG-13
# 250                  The Waterboy  PG-13
# 251    10 Things I Hate About You  PG-13
# 253  How to Lose a Guy in 10 Days  PG-13
# 254              The Benchwarmers  PG-13
# 255                       Step Up  PG-13
# 257                      Twilight  PG-13
# 273                  Mean Girls 2  PG-13
# 286                    Safe Haven  PG-13
# 300                  The Waterboy  PG-13
# 302           The Wedding Planner  PG-13
# 306                      Twilight  PG-13
# 322                  Mean Girls 2  PG-13
# 335        Trouble with the Curve  PG-13
# 372                 Unconditional  PG-13
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 250               language and some crude sexual humor                 80
# 251    adult content, adult language and mild violence                 80
# ...

# %%
data.loc[(data.rating=='R')]
# Out:
#                                   title rating  \
# 1                   Lucky Number Slevin      R
# 14                           The Hunter      R
# 35                           Hyena Road      R
# 50                  Lucky Number Slevin      R
# 87                      Meet the Blacks      R
# 90                        Sausage Party      R
# 92                Kevin Hart: What Now?      R
# 100  The Life Aquatic with Steve Zissou      R
# 101                 Lucky Number Slevin      R
# 117                              5 to 7      R
# 150                        The Brothers      R
# 170                                Dope      R
# 217        The Angriest Man in Brooklyn      R
# 218                              5 to 7      R
# 303                                Blow      R
# 334                          Magic Mike      R
# 344                       Sausage Party      R
# 381                   London Has Fallen      R
# 431                   London Has Fallen      R
#
# ...

# %%
data.loc[(data.rating=='R') & (data['release year']==2016) | (data.rating=='R') & (data['release year']==2015)] #dont use and, or keywords
# Out:
#                      title rating  \
# 35              Hyena Road      R
# 87         Meet the Blacks      R
# 90           Sausage Party      R
# 92   Kevin Hart: What Now?      R
# 170                   Dope      R
# 344          Sausage Party      R
# 381      London Has Fallen      R
# 431      London Has Fallen      R
#
#                                            ratingLevel  ratingDescription  \
# 35   bloody war violence, language throughout and s...                100
# 87   pervasive language, some sexual material, viol...                100
# 90   strong crude sexual content, pervasive languag...                100
# 92       some sexual material, and language throughout                100
# 170  language, drug content, sexuality/nudity, and ...                100
# 344  strong crude sexual content, pervasive languag...                100
# 381            strong violence and language throughout                100
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22028\3113421921.py in <module>
# ----> 1 data.null().sum()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5581         ):
#    5582             return self[name]
# -> 5583         return object.__getattribute__(self, name)
#    5584
#    5585     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'null'
